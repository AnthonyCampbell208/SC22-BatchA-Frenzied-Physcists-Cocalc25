# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("./Data/Top_YouTube_Channels_Data.csv")

# %%
df.head(50)
# Out:
#     rank                                            youtuber  subscribers   \
# 0       1                                          T-Series      213000000
# 1       2                                    YouTube Movies      150000000
# 2       3                        Cocomelon - Nursery Rhymes      133000000
# 3       4                                         SET India      131000000
# 4       5                                             Music      116000000
# 5       6                                         PewDiePie      111000000
# 6       7                                           MrBeast       93900000
# 7       8                                   Kids Diana Show       93800000
# 8       9                                            Gaming       92100000
# 9      10                                        Like Nastya      91000000
# 10     11                                               WWE       87600000
# ...

# %%
print(df.columns)
# Out:
# Index(['rank ', 'youtuber', 'subscribers ', 'video views ', 'video count ',
#        'category ', 'started '],
#       dtype='object')

# %%
fig = px.bar(df, x='category ', y='subscribers ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df, x="video views ", y="subscribers ")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df, x="started ", y="subscribers ")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df, x="video views ", y="category ", color="started ",
                 size='subscribers ', hover_data=['video count '])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
